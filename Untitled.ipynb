# %%
#IMPORTATION DES DIFFERENTES MODULES NECESSAIRE
import pandas as pd
import numpy as np

# %%
#CREATION DE LA DATAFRAME A PARTIR DU FICHIER toy_incomplet.csv
DataFrame = pd.read_csv("toy_incomplet.csv", encoding="UTF-8", sep='\t')
DataFrameC= pd.read_csv("toy_complet.csv", encoding="UTF-8", sep='\t')

# %%
#Affichage du dataframe
DataFrame
# Out:
#     Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 0     1.808796    2.765099           1    4.193392    3.593898           2
# 1    -1.000000    2.000000           2   -1.000000    0.000000           2
# 2    -1.000000   -1.000000          -1   -1.000000   -1.000000           0
# 3    -1.000000   -1.000000           2    0.000000    3.000000           0
# 4    -1.000000   -1.000000          -1    1.000000    2.000000           0
# ..         ...         ...         ...         ...         ...         ...
# 95    1.000000    4.000000          -1    0.000000    3.000000           0
# 96   -1.000000    1.000000           1   -1.000000   -1.000000           2
# 97   -1.000000   -1.000000          -1   -1.000000    3.000000           4
# 98    4.000000   -1.000000          -1    4.000000   -1.000000          -1
# 99    1.000000    4.000000          -1   -1.000000    3.000000          -1
#
#     Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10  ...  Unnamed: 991  \
# 0     0.985554    2.181051    2.866488      2.42347  ...            -1
# 1    -1.000000    4.000000   -1.000000      1.00000  ...            -1
# 2     2.000000   -1.000000    4.000000      3.00000  ...             1
# 3    -1.000000    1.000000    4.000000     -1.00000  ...             1
# 4     2.000000    1.000000    4.000000      4.00000  ...             1
# ..         ...         ...         ...          ...  ...           ...
# 95    2.000000    1.000000    4.000000     -1.00000  ...            -1
# 96    4.000000    4.000000   -1.000000      0.00000  ...             1
# 97    3.000000   -1.000000   -1.000000      3.00000  ...             3
# 98    3.000000    4.000000   -1.000000     -1.00000  ...            -1
# 99    4.000000    1.000000    3.000000     -1.00000  ...             1
#
#     Unnamed: 992  Unnamed: 993  Unnamed: 994  Unnamed: 995  Unnamed: 996  \
# 0             -1            -1             4            -1             0
# 1              4             3            -1             2             3
# 2              0             2            -1            -1            -1
# 3              1            -1             1             4            -1
# 4              1             1            -1            -1             3
# ..           ...           ...           ...           ...           ...
# 95            -1            -1             1             3            -1
# 96            -1             4            -1             3            -1
# 97             0             3            -1            -1            -1
# 98            -1             4            -1             2             3
# 99             5            -1            -1             5            -1
#
#     Unnamed: 997  Unnamed: 998  Unnamed: 999  Unnamed: 1000
# 0             -1            -1             4             -1
# 1             -1            -1             4              1
# 2             -1             1             5              0
# 3             -1            -1            -1              0
# 4              4             3             3              1
# ..           ...           ...           ...            ...
# 95            -1            -1             4             -1
# 96             0             2            -1             -1
# 97            -1            -1             2              2
# 98             0             2            -1              2
# 99            -1            -1             1              4
#
# [100 rows x 1000 columns]

# %%
DataFrameC.head()
# Out:
#    Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0         NaN           1           2           1           5           4
# 1         NaN           3           2           2           3           0
# 2         NaN           0           4           2           1           4
# 3         NaN           0           4           2           0           3
# 4         NaN           0           5           2           1           2
#
#    Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  Unnamed: 991  \
# 0           2           0           2           4  ...             3
# 1           2           4           4           4  ...             1
# 2           0           2           1           4  ...             1
# 3           0           2           1           4  ...             1
# 4           0           2           1           4  ...             1
#
#    Unnamed: 992  Unnamed: 993  Unnamed: 994  Unnamed: 995  Unnamed: 996  \
# 0             0             4             4             3             0
# 1             4             3             1             2             3
# 2             0             2             2             3             3
# 3             1             1             1             4             2
# 4             1             1             1             3             3
#
#    Unnamed: 997  Unnamed: 998  Unnamed: 999  Unnamed: 1000
# 0             1             1             4              4
# 1             0             2             4              1
# 2             5             1             5              0
# 3             5             2             4              0
# 4             4             3             3              1
#
# [5 rows x 1001 columns]

# %%
#SELECTION DE LA COLONNE AVEC LES NaN
column_with_nan = DataFrame.columns[DataFrame.isnull().any()]
column_with_nanC = DataFrameC.columns[DataFrame.isnull().any()]

# %%
#SUPPRESSION DE LA COLONNE AVEC LES NaN
DataFrame.drop(column_with_nan,1,inplace=True)
DataFrameC.drop(column_with_nan,1,inplace=True)
DataFrame.head()
# Out:
#    Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 0          -1          -1           1          -1          -1           2
# 1          -1           2           2          -1           0           2
# 2          -1          -1          -1          -1          -1           0
# 3          -1          -1           2           0           3           0
# 4          -1          -1          -1           1           2           0
#
#    Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10  ...  Unnamed: 991  \
# 0          -1          -1          -1           -1  ...            -1
# 1          -1           4          -1            1  ...            -1
# 2           2          -1           4            3  ...             1
# 3          -1           1           4           -1  ...             1
# 4           2           1           4            4  ...             1
#
#    Unnamed: 992  Unnamed: 993  Unnamed: 994  Unnamed: 995  Unnamed: 996  \
# 0            -1            -1             4            -1             0
# 1             4             3            -1             2             3
# 2             0             2            -1            -1            -1
# 3             1            -1             1             4            -1
# 4             1             1            -1            -1             3
#
#    Unnamed: 997  Unnamed: 998  Unnamed: 999  Unnamed: 1000
# 0            -1            -1             4             -1
# 1            -1            -1             4              1
# 2            -1             1             5              0
# 3            -1            -1            -1              0
# 4             4             3             3              1
#
# [5 rows x 1000 columns]

# %%
DataFrameC.head()
# Out:
#    Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 0           1           2           1           5           4           2
# 1           3           2           2           3           0           2
# 2           0           4           2           1           4           0
# 3           0           4           2           0           3           0
# 4           0           5           2           1           2           0
#
#    Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10  ...  Unnamed: 991  \
# 0           0           2           4            2  ...             3
# 1           4           4           4            1  ...             1
# 2           2           1           4            3  ...             1
# 3           2           1           4            3  ...             1
# 4           2           1           4            4  ...             1
#
#    Unnamed: 992  Unnamed: 993  Unnamed: 994  Unnamed: 995  Unnamed: 996  \
# 0             0             4             4             3             0
# 1             4             3             1             2             3
# 2             0             2             2             3             3
# 3             1             1             1             4             2
# 4             1             1             1             3             3
#
#    Unnamed: 997  Unnamed: 998  Unnamed: 999  Unnamed: 1000
# 0             1             1             4              4
# 1             0             2             4              1
# 2             5             1             5              0
# 3             5             2             4              0
# 4             4             3             3              1
#
# [5 rows x 1000 columns]

# %%
#CALCUL DES 10 premières similarités pearson entre 0 et (1,10)
#En excluant les valeurs inconnues -1
listeSimPearson = []
for i in range(1,10):
    moyennei=0
    moyennej=0

    #moyenne des notes de i à j
    x=0
    for j in range(0,DataFrame.shape[1]-1):
        if (DataFrame.iloc[0,j]!=-1 and DataFrame.iloc[i,j]!=-1):
            moyennei=moyennei+DataFrame.iloc[0,j]
            x=x+1
    moyennei=moyennei/x

    #moyenne des notes de k à j
    x=0
    for j in range(0,DataFrame.shape[1]-1):
        if(DataFrame.iloc[i,j]!=-1 and DataFrame.iloc[0,j]!=-1):
            moyennej=moyennej+DataFrame.iloc[i,j]
            x=x+1
    moyennej=moyennej/x


    Somme =0
    for j in range (0,DataFrame.shape[1]-1):
        if(DataFrame.iloc[i,j]!=-1 and DataFrame.iloc[0,j]!=-1):
            Somme=Somme + (DataFrame.iloc[0,j]-moyennei)*(DataFrame.iloc[i,j]-moyennej)


    s1=0
    s2=0
    for j in range (0,DataFrame.shape[1]-1):
        if(DataFrame.iloc[i,j]!=-1 and DataFrame.iloc[0,j]!=-1):
            s1=s1+(DataFrame.iloc[0,j]-moyennei)**2

    for j in range (0,DataFrame.shape[1]-1):
        if(DataFrame.iloc[i,j]!=-1 and DataFrame.iloc[0,j]!=-1):
            s2=s2+(DataFrame.iloc[i,j]-moyennej)**2

    denominateur= np.sqrt(s1*s2)
    simPearson=Somme/denominateur
    listeSimPearson.append(simPearson)
print(listeSimPearson)

def SimPearson(i,k):
    moyennei=0
    moyennej=0

    #moyenne des notes de i à j
    x=0
    for j in range(0,DataFrame.shape[1]-1):
        if (DataFrame.iloc[i,j]!=-1 and DataFrame.iloc[k,j]!=-1):
            moyennei=moyennei+DataFrame.iloc[i,j]
            x=x+1
    moyennei=moyennei/x

    #moyenne des notes de k à j
    x=0
    for j in range(0,DataFrame.shape[1]-1):
        if(DataFrame.iloc[k,j]!=-1 and DataFrame.iloc[i,j]!=-1):
            moyennej=moyennej+DataFrame.iloc[k,j]
            x=x+1
    moyennej=moyennej/x


    Somme =0
    for j in range (0,DataFrame.shape[1]-1):
        if(DataFrame.iloc[k,j]!=-1 and DataFrame.iloc[i,j]!=-1):
            Somme=Somme + (DataFrame.iloc[i,j]-moyennei)*(DataFrame.iloc[k,j]-moyennej)


    s1=0
    s2=0
    for j in range (0,DataFrame.shape[1]-1):
        if(DataFrame.iloc[k,j]!=-1 and DataFrame.iloc[i,j]!=-1):
            s1=s1+(DataFrame.iloc[i,j]-moyennei)**2

    for j in range (0,DataFrame.shape[1]-1):
        if(DataFrame.iloc[k,j]!=-1 and DataFrame.iloc[i,j]!=-1):
            s2=s2+(DataFrame.iloc[k,j]-moyennej)**2

    denominateur= np.sqrt(s1*s2)
    simPearson=Somme/denominateur
    return simPearson
print(SimPearson(0,0))

#COSINUS

def SimCos(i, k) :
    Somme = 0
    for j in range(0, DataFrame.shape[1] - 1) :
            if(DataFrame.iloc[i,j] != -1 and DataFrame.iloc[k,j] != -1) :
                Somme = Somme + DataFrame.iloc[0,j] * DataFrame.iloc[k,j]

    Sommeij = 0
    Sommekj = 0
    for j in range(0, DataFrame.shape[1] - 1) :
        if(DataFrame.iloc[i,j] != -1 and DataFrame.iloc[k,j] != -1) :
            Sommeij = Sommeij + (DataFrame.iloc[0,j])2

    for j in range(0, DataFrame.shape[1] - 1) :
         if(DataFrame.iloc[i,j] != -1 and DataFrame.iloc[k,j] != -1) :
            Sommekj = Sommekj + (DataFrame.iloc[k,j])2

    denominateur = np.sqrt(Sommeij * Sommekj)
    CosineSim = Somme / denominateur
    return CosineSim
# Out:
# [-0.021661869531394887, 0.015390103569049057, -0.0031177700981050663, -0.03625633827095498, 0.8704091888652138, -0.017336565524381967, 0.04239681505009819, -0.041776380517848946, -0.04073206363690865]
# 1.0

# %%
#Calcul des similarités
SimilaritesPearson= np.zeros(shape=(DataFrame.shape[0],DataFrame.shape[0]))
for i in range(0,DataFrame.shape[0]-1):
    for j in range(0,DataFrame.shape[0]-1):
        SimilaritesPearson[i][j]=SimPearson(i,j)
print(SimilaritesPearson)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-53-0a6ed24c6d13> in <module>
#       3 for i in range(0,DataFrame.shape[0]-1):
#       4     for j in range(0,DataFrame.shape[0]-1):
# ----> 5         SimilaritesPearson.iloc[i,j]=SimPearson(i,j)
#       6 print(SimilaritesPearson)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     202         else:
#     203             key = com.apply_if_callable(key, self.obj)
# --> 204         indexer = self._get_setitem_indexer(key)
#     205         self._setitem_with_indexer(indexer, value)
#     206
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_setitem_indexer(self, key)
#     180         if isinstance(key, tuple):
#     181             try:
# --> 182                 return self._convert_tuple(key, is_setter=True)
#     183             except IndexingError:
#     184                 pass
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_tuple(self, key, is_setter)
#     260                 if i >= self.obj.ndim:
#     261                     raise IndexingError("Too many indexers")
# --> 262                 idx = self._convert_to_indexer(k, axis=i, is_setter=is_setter)
#     263                 keyidx.append(idx)
#     264         return tuple(keyidx)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    2173
#    2174         try:
# -> 2175             self._validate_key(obj, axis)
#    2176             return obj
#    2177         except ValueError:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_key(self, key, axis)
#    2012             return
#    2013         elif is_integer(key):
# -> 2014             self._validate_integer(key, axis)
#    2015         elif isinstance(key, tuple):
#    2016             # a tuple should already have been caught by this point
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_integer(self, key, axis)
#    2086         len_axis = len(self.obj._get_axis(axis))
#    2087         if key >= len_axis or key < -len_axis:
# -> 2088             raise IndexError("single positional indexer is out-of-bounds")
#    2089
#    2090     def _getitem_tuple(self, tup):
#
# IndexError: single positional indexer is out-of-bounds

# %%
SimilaritesPearson
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
pd.DataFrame(SimilaritesPearson).to_csv("Similarités_Pearson.csv",index=False)

# %%
DF=pd.read_csv("Similarités_Pearson.csv")
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# <ipython-input-61-9391201c7184> in <module>
# ----> 1 DF=pd.read_csv("Similarités_Pearson.csv")
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1133     def _make_engine(self, engine="c"):
#    1134         if engine == "c":
# -> 1135             self._engine = CParserWrapper(self.f, **self.options)
#    1136         else:
#    1137             if engine == "python":
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1915         kwds["usecols"] = self.usecols
#    1916
# -> 1917         self._reader = parsers.TextReader(src, **kwds)
#    1918         self.unnamed_cols = self._reader.unnamed_cols
#    1919
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# EmptyDataError: No columns to parse from file

# %%
DF
# Out:
#     Unnamed: 0         0         1         2         3         4         5  \
# 0            0  1.000000 -0.021662  0.015390 -0.003118 -0.036256  0.870409
# 1            1 -0.021662  1.000000 -0.019273 -0.027105  0.036643 -0.046805
# 2            2  0.015390 -0.019273  1.000000  0.856374  0.829841 -0.046966
# 3            3 -0.003118 -0.027105  0.856374  1.000000  0.860838 -0.097306
# 4            4 -0.036256  0.036643  0.829841  0.860838  1.000000 -0.116213
# ..         ...       ...       ...       ...       ...       ...       ...
# 94          94 -0.061829 -0.126296  0.024639  0.140522  0.001144 -0.029026
# 95          95 -0.044545 -0.002248  0.854322  0.890402  0.881536 -0.038374
# 96          96  0.019616  0.880697 -0.011382 -0.055188 -0.074526 -0.094069
# 97          97  0.073668 -0.095837  0.025856  0.113732  0.046670  0.049302
# 98          98 -0.079893  0.874883 -0.023972 -0.032795  0.045689 -0.050205
#
#            6         7         8  ...        89        90        91        92  \
# 0  -0.017337  0.042397 -0.041776  ... -0.026210  0.882206  0.889632  0.059163
# 1   0.035971 -0.076763  0.871163  ... -0.115833 -0.043490 -0.045353 -0.093521
# 2   0.876175 -0.037665 -0.073878  ... -0.089919  0.093388  0.062599  0.032722
# 3   0.872071  0.075814 -0.013309  ...  0.072422  0.046658 -0.036916  0.096954
# 4   0.873778 -0.026580  0.002403  ... -0.015072 -0.013525 -0.071596 -0.009603
# ..       ...       ...       ...  ...       ...       ...       ...       ...
# 94  0.072900  0.884804 -0.108605  ...  0.889671  0.038331  0.076430  0.874508
# 95  0.874126  0.072492 -0.130477  ...  0.045677  0.053944  0.039380  0.089466
# 96 -0.016439  0.038338  0.867169  ... -0.089048  0.082239  0.053568 -0.050615
# 97  0.075336  0.857010 -0.053267  ...  0.884482  0.078160  0.125516  0.881356
# 98  0.043355 -0.037745  0.846426  ... -0.078871  0.023598  0.018011 -0.062442
#
#           93        94        95        96        97        98
# 0   0.073918 -0.061829 -0.044545  0.019616  0.073668 -0.079893
# 1  -0.037935 -0.126296 -0.002248  0.880697 -0.095837  0.874883
# 2   0.061937  0.024639  0.854322 -0.011382  0.025856 -0.023972
# 3   0.007351  0.140522  0.890402 -0.055188  0.113732 -0.032795
# 4  -0.076574  0.001144  0.881536 -0.074526  0.046670  0.045689
# ..       ...       ...       ...       ...       ...       ...
# 94  0.884429  1.000000  0.084522 -0.057647  0.860088 -0.094200
# 95  0.040466  0.084522  1.000000 -0.007298  0.053789 -0.050558
# 96 -0.030922 -0.057647 -0.007298  1.000000 -0.116449  0.851023
# 97  0.886893  0.860088  0.053789 -0.116449  1.000000 -0.060752
# 98 -0.081337 -0.094200 -0.050558  0.851023 -0.060752  1.000000
#
# [99 rows x 100 columns]

# %%
#Npredite de lutilisateur 0 sur l'item 1 (filtrage utilisateur)

def prediction(u1,i1):
    num=0
    den=0
    moyenne0=0
    c=0
    for x in range(0,DataFrame.shape[1]-1):
        if DataFrame.iloc[u1,x]!=-1:
            moyenne0+=DataFrame.iloc[u1,x]
            c+=1
    moyenne0=moyenne0/c


    for i in range(0,DataFrame.shape[0]-1):
        moyennei=0
        c=0
        for j in range(0,DataFrame.shape[1]-1):
            if DataFrame.iloc[i,j]!=-1:
                moyennei+=DataFrame.iloc[i,j]
                c+=1
        moyennei=moyennei/c

        if DataFrame.iloc[i,i1]!=-1 and SimilaritesPearson[u1][i]>0.8:
            num=num+SimilaritesPearson[u1][i]*(DataFrame.iloc[i,i1]-moyennei)
            den=den+SimilaritesPearson[u1][i]

    return moyenne0+(num/den)

print(prediction(0,1))
# Out:
# 2.7690361022427474

# %%
for i in range(0,DataFrame.shape[0]-1):
    for j in range(0,DataFrame.shape[1]-1):
        if DataFrame.iloc[i,j]==-1:
            DataFrame.iloc[i,j]=prediction(i,j)
DataFrame.head()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-a1a845bd6bd9> in <module>
#       2     for j in range(0,DataFrame.shape[1]-1):
#       3         if DataFrame.iloc[i,j]==-1:
# ----> 4             DataFrame.iloc[i,j]=prediction(i,j)
#       5 DataFrame.head()
#
# <ipython-input-24-bfcd7e6c4f80> in prediction(u1, i1)
#      17         c=0
#      18         for j in range(0,DataFrame.shape[1]-1):
# ---> 19             if DataFrame.iloc[i,j]!=-1:
#      20                 moyennei+=DataFrame.iloc[i,j]
#      21                 c+=1
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1410     def __getitem__(self, key):
#    1411         if type(key) is tuple:
# -> 1412             key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#    1413             if self._is_scalar_access(key):
#    1414                 try:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in <genexpr>(.0)
#    1410     def __getitem__(self, key):
#    1411         if type(key) is tuple:
# -> 1412             key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#    1413             if self._is_scalar_access(key):
#    1414                 try:
#
# KeyboardInterrupt:
